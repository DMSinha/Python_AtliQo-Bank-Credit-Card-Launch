# %%
import pandas as pd 
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")
import mysql.connector

# %%
df_cust= pd.read_csv(r"C:\Users\divya\Statistics\AtliQo Bank Project\chapter8_assets\chapter8_assets\datasets\customers.csv")

# %%
df_cp = pd.read_csv(r"C:\Users\divya\Statistics\AtliQo Bank Project\chapter8_assets\chapter8_assets\datasets\credit_profiles.csv")

# %%
df_trans = pd.read_csv(r"C:\Users\divya\Statistics\AtliQo Bank Project\chapter8_assets\chapter8_assets\datasets\transactions.csv")

# %%
df_cust.head()
# Out:
#    cust_id            name  gender  age location      occupation  \
# 0        1   Manya Acharya  Female    2     City  Business Owner
# 1        2   Anjali Pandey  Female   47     City      Consultant
# 2        3  Aaryan Chauhan    Male   21     City      Freelancer
# 3        4      Rudra Bali    Male   24    Rural      Freelancer
# 4        5    Advait Malik    Male   48     City      Consultant
#
#    annual_income marital_status
# 0       358211.0        Married
# 1        65172.0         Single
# 2        22378.0        Married
# 3        33563.0        Married
# 4        39406.0        Married

# %%
import mysql.connector
conn = mysql.connector.connect(
       host='localhost',
    user='root',
    password='root',
    database='e_master_card'
)

# %%
df_sql_cust = pd.read_sql("Select * from customers",conn)
df_sql_cust.head()
# Out:
#    cust_id            name  gender  age location      occupation  \
# 0        1   Manya Acharya  Female    2     City  Business Owner
# 1        2   Anjali Pandey  Female   47     City      Consultant
# 2        3  Aaryan Chauhan    Male   21     City      Freelancer
# 3        4      Rudra Bali    Male   24    Rural      Freelancer
# 4        5    Advait Malik    Male   48     City      Consultant
#
#    annual_income marital_status
# 0         358211        Married
# 1          65172         Single
# 2          22378        Married
# 3          33563        Married
# 4          39406        Married

# %%
df_sql_cp = pd.read_sql("Select * from credit_profiles",conn)
df_sql_cp.head()
# Out:
#    cust_id  credit_score  credit_utilisation  outstanding_debt  \
# 0        1           749            0.585171           19571.0
# 1        2           587            0.107928          161644.0
# 2        3           544            0.854807             513.0
# 3        4           504            0.336938             224.0
# 4        5           708            0.586151           18090.0
#
#    credit_inquiries_last_6_months  credit_limit
# 0                             0.0       40000.0
# 1                             2.0        1250.0
# 2                             4.0        1000.0
# 3                             2.0        1000.0
# 4                             2.0       40000.0

# %%
df_sql_trans = pd.read_sql("Select * from transactions",conn)
df_sql_trans.head()
# Out:
#    tran_id  cust_id   tran_date  tran_amount  platform   product_category  \
# 0        1      705  2023-01-01           63  Flipkart        Electronics
# 1        2      385  2023-01-01           99   Alibaba  Fashion & Apparel
# 2        3      924  2023-01-01          471   Shopify             Sports
# 3        4      797  2023-01-01           33   Shopify  Fashion & Apparel
# 4        5      482  2023-01-01           68    Amazon  Fashion & Apparel
#
#   payment_type
# 0      Phonepe
# 1  Credit Card
# 2      Phonepe
# 3         Gpay
# 4  Net Banking

# %%
df_cust.describe()
# Out:
#            cust_id          age  annual_income
# count  1000.000000  1000.000000     950.000000
# mean    500.500000    36.405000  139410.314737
# std     288.819436    15.666155  112416.802007
# min       1.000000     1.000000       2.000000
# 25%     250.750000    26.000000   47627.500000
# 50%     500.500000    32.000000  112218.500000
# 75%     750.250000    46.000000  193137.500000
# max    1000.000000   135.000000  449346.000000

# %%
df_cust.isnull().sum()
# Out:
# cust_id            0
# name               0
# gender             0
# age                0
# location           0
# occupation         0
# annual_income     50
# marital_status     0
# dtype: int64

# %%
df_cust.head(20)
# Out:
#     cust_id               name  gender  age location           occupation  \
# 0         1      Manya Acharya  Female    2     City       Business Owner
# 1         2      Anjali Pandey  Female   47     City           Consultant
# 2         3     Aaryan Chauhan    Male   21     City           Freelancer
# 3         4         Rudra Bali    Male   24    Rural           Freelancer
# 4         5       Advait Malik    Male   48     City           Consultant
# 5         6           Arya Das    Male   22     City           Freelancer
# 6         7       Avyanna Soni  Female   32   Suburb       Business Owner
# 7         8      Yash Vernekar    Male   27     City           Freelancer
# 8         9     Vihaan Agarwal    Male   21   Suburb  Fullstack Developer
# 9        10   Aditya Choudhary    Male   25    Rural           Freelancer
# 10       11  Krishna Singhania    Male   39     City           Accountant
# 11       12        Krishna Das    Male   36     City           Accountant
# ...

# %%
df_cust[df_cust.annual_income.isna()].head(4)
# Out:
#      cust_id               name  gender  age location      occupation  \
# 14        15      Sanjana Malik  Female   25    Rural          Artist
# 82        83  Reyansh Mukherjee    Male   27     City      Freelancer
# 97        98         Virat Puri    Male   47   Suburb  Business Owner
# 102      103         Aarav Shah    Male   32     City  Data Scientist
#
#      annual_income marital_status
# 14             NaN        Married
# 82             NaN         Single
# 97             NaN        Married
# 102            NaN        Married

# %%
#Annual Income Median
df_cust.annual_income.median()
# Out:
# 112218.5

# %%
df_cust[df_cust.occupation=="Artist"].annual_income.median()
# Out:
# 45794.0

# %%
df_cust[df_cust.occupation=="Freelancer"].annual_income.median()
# Out:
# 46759.0

# %%
df_cust[df_cust.occupation=="Data Scientist"].annual_income.median()
# Out:
# 135759.0

# %%
df_cust[df_cust.occupation=="Business Owner"].annual_income.median()
# Out:
# 261191.5

# %%
occupation_wise_inc_median = df_cust.groupby("occupation")["annual_income"].median()
occupation_wise_inc_median
# Out:
# occupation
# Accountant              65265.0
# Artist                  45794.0
# Business Owner         261191.5
# Consultant              58017.0
# Data Scientist         135759.0
# Freelancer              46759.0
# Fullstack Developer     76774.0
# Name: annual_income, dtype: float64

# %%
occupation_wise_inc_median["Artist"]
# Out:
# 45794.0

# %%
def get_median_val(row):
    if pd.isnull(row["annual_income"]):
        return occupation_wise_inc_median[row["occupation"]]
    else:
        return row["annual_income"]

# %%
get_median_val({"cust_id":2345,"occupation":"Artist","annual_income":None})
# Out:
# 45794.0

# %%
df_cust["annual_income"]
# Out:
# 0      358211.0
# 1       65172.0
# 2       22378.0
# 3       33563.0
# 4       39406.0
#          ...
# 995         NaN
# 996    290061.0
# 997    139141.0
# 998         NaN
# 999    226873.0
# Name: annual_income, Length: 1000, dtype: float64

# %%
df_cust["annual_income"] = df_cust.apply(
        lambda row: occupation_wise_inc_median[row["occupation"]] if pd.isnull(row["annual_income"]) else row["annual_income"],
        axis = 1
)

# %%
df_cust.isnull().sum()
# Out:
# cust_id           0
# name              0
# gender            0
# age               0
# location          0
# occupation        0
# annual_income     0
# marital_status    0
# dtype: int64

# %%
df_cust.iloc[[14,82]]
# Out:
#     cust_id               name  gender  age location  occupation  \
# 14       15      Sanjana Malik  Female   25    Rural      Artist
# 82       83  Reyansh Mukherjee    Male   27     City  Freelancer
#
#     annual_income marital_status
# 14        45794.0        Married
# 82        46759.0         Single

# %%
plt.figure(figsize=(5,5))
sns.histplot(df_cust['annual_income'],kde=True,color='green',label='Data')
plt.title("Histogram of annual income")
plt.show()

# %%
#Data Cleaning: Treating Outliers
df_cust.describe()
# Out:
#            cust_id          age  annual_income
# count  1000.000000  1000.000000    1000.000000
# mean    500.500000    36.405000  138916.765500
# std     288.819436    15.666155  110969.408643
# min       1.000000     1.000000       2.000000
# 25%     250.750000    26.000000   48229.500000
# 50%     500.500000    32.000000  113416.000000
# 75%     750.250000    46.000000  192614.000000
# max    1000.000000   135.000000  449346.000000

# %%
#Business Manager said that annual income should be above 100
df_cust[df_cust.annual_income<100]
# Out:
#      cust_id            name  gender  age location           occupation  \
# 31        32     Veer Mistry    Male   50     City       Business Owner
# 262      263   Vivaan Tandon    Male   53   Suburb       Business Owner
# 316      317   Yuvraj Saxena    Male   47     City           Consultant
# 333      334    Avani Khanna  Female   29     City       Data Scientist
# 340      341     Priya Sinha  Female   33    Rural  Fullstack Developer
# 543      544    Advait Batra    Male   54     City           Consultant
# 592      593    Priya Gandhi  Female   32     City       Business Owner
# 633      634   Rudra Mehtani    Male   26     City       Data Scientist
# 686      687  Vihaan Jaiswal    Male   40     City       Business Owner
# 696      697      Ishan Negi    Male   47     City           Consultant
#
#      annual_income marital_status
# 31            50.0        Married
# 262           50.0        Married
# 316           50.0        Married
# 333           50.0        Married
# ...

# %%
for index, row in df_cust.iterrows():
    if row["annual_income"]<100:
       df_cust.at[index,"annual_income"] = occupation_wise_inc_median[row["occupation"]]

# %%
#Business Manager said that annual income should be above 100
df_cust[df_cust.annual_income<100]

#We can see now no records with annual income less than 100 exist
# Out:
# Empty DataFrame
# Columns: [cust_id, name, gender, age, location, occupation, annual_income, marital_status]
# Index: []

# %%
df_cust.loc[[31,316]]
# Out:
#      cust_id           name gender  age location      occupation  \
# 31        32    Veer Mistry   Male   50     City  Business Owner
# 316      317  Yuvraj Saxena   Male   47     City      Consultant
#
#      annual_income marital_status
# 31        261191.5        Married
# 316        58017.0        Married

# %%
#Data Visualization: Annual Income
avg_income_per_occupation = df_cust.groupby("occupation")["annual_income"].mean()
avg_income_per_occupation
# Out:
# occupation
# Accountant              64123.562500
# Artist                  45309.236842
# Business Owner         268447.368512
# Consultant              60703.154639
# Data Scientist         137021.266304
# Freelancer              76327.508772
# Fullstack Developer     78727.972973
# Name: annual_income, dtype: float64

# %%
avg_income_per_occupation.index
# Out:
# Index(['Accountant', 'Artist', 'Business Owner', 'Consultant',
#        'Data Scientist', 'Freelancer', 'Fullstack Developer'],
#       dtype='object', name='occupation')

# %%
avg_income_per_occupation.values
# Out:
# array([ 64123.5625    ,  45309.23684211, 268447.36851211,  60703.15463918,
#        137021.26630435,  76327.50877193,  78727.97297297])

# %%
sns.barplot(x=avg_income_per_occupation.index,y=avg_income_per_occupation.values, palette="tab10")
plt.xticks(rotation=45)
plt.show()
plt.title("Avg Annual Income Per Occupation")
plt.xlabel("Occupation")
plt.ylabel("Average Annual Income ($)")

plt.show()

# %%
### Plotting Average Annual Income: against 'gender', 'location', 'occupation', 'marital_status'

categorical_columns = ['gender', 'location', 'occupation', 'marital_status']
for col in categorical_columns:
    plt.figure(figsize=(8,4))
    avg_income_per_group = df_cust.groupby(col)['annual_income'].mean().sort_values()
    sns.barplot(x=avg_income_per_group.index,y=avg_income_per_group.values,palette='tab10')
    plt.xticks(rotation=45)
    plt.title("Avg Annual Income Per Occupation {col.capitalize()}")
    plt.xlabel(col.capitalize())
    plt.ylabel("Average Annual Income ($)")
    plt.show()

# %% [markdown]
# <h2>Analyze Age Column</h2>

# %% [markdown]
# Handle Null Values: Age Column
# First let us check if there are any NULL values in the Age Column

# %%
#This will give null values for each column
df_cust.isnull().sum()
# Out:
# cust_id           0
# name              0
# gender            0
# age               0
# location          0
# occupation        0
# annual_income     0
# marital_status    0
# dtype: int64

# %%
df_cust.age.describe()
# Out:
# count    1000.000000
# mean       36.405000
# std        15.666155
# min         1.000000
# 25%        26.000000
# 50%        32.000000
# 75%        46.000000
# max       135.000000
# Name: age, dtype: float64

# %%
plt.hist(df_cust.age,bins = 20, edgecolor="black")
plt.show()

# %%
outliers = df_cust[(df_cust.age<15)|(df_cust.age>80)]
outliers
# Out:
#      cust_id             name  gender  age location           occupation  \
# 0          1    Manya Acharya  Female    2     City       Business Owner
# 41        42      Aaryan Shah    Male  110     City               Artist
# 165      166        Sia Dutta  Female    1     City           Freelancer
# 174      175     Rohan Sharma    Male  110     City           Freelancer
# 222      223      Arjun Batra    Male  110   Suburb           Freelancer
# 277      278     Aarav Tandon    Male  110     City           Consultant
# 295      296     Ayush Pandey    Male    1    Rural           Accountant
# 325      326       Virat Goel    Male  110     City           Accountant
# 610      611      Rehan Verma    Male  135    Rural       Business Owner
# 692      693        Dhruv Jha    Male    1     City       Business Owner
# 703      704     Aanya Sharma  Female  110     City           Freelancer
# 709      710      Anika Verma  Female  110     City       Data Scientist
# ...

# %%
outliers.shape
# Out:
# (20, 8)

# %%
df_cust.age.median()
# Out:
# 32.0

# %%
median_age_per_occupation = df_cust.groupby("occupation")["age"].median()
median_age_per_occupation
# Out:
# occupation
# Accountant             31.5
# Artist                 26.0
# Business Owner         51.0
# Consultant             46.0
# Data Scientist         32.0
# Freelancer             24.0
# Fullstack Developer    27.5
# Name: age, dtype: float64

# %%
#Replacing values in main dataframe with median value, by iterating outliers dataframe
for index, row in outliers.iterrows():
    df_cust.at[index,'age'] = median_age_per_occupation[row['occupation']]

# %%
outliers = df_cust[(df_cust.age<15)|(df_cust.age>80)]
outliers
# Out:
# Empty DataFrame
# Columns: [cust_id, name, gender, age, location, occupation, annual_income, marital_status]
# Index: []

# %%
df_cust.describe()
# Out:
#            cust_id          age  annual_income
# count  1000.000000  1000.000000    1000.000000
# mean    500.500000    35.541500  140483.548500
# std     288.819436    12.276634  110463.002934
# min       1.000000    18.000000    5175.000000
# 25%     250.750000    26.000000   49620.500000
# 50%     500.500000    32.000000  115328.000000
# 75%     750.250000    44.250000  195514.250000
# max    1000.000000    64.000000  449346.000000

# %%
bins_edges = [17,25,48,65]
bins_labels = ['18-25','26-48','49-65']

df_cust['age_group']=pd.cut(df_cust['age'],bins=bins_edges,labels=bins_labels)
df_cust.head()
# Out:
#    cust_id            name  gender   age location      occupation  \
# 0        1   Manya Acharya  Female  51.0     City  Business Owner
# 1        2   Anjali Pandey  Female  47.0     City      Consultant
# 2        3  Aaryan Chauhan    Male  21.0     City      Freelancer
# 3        4      Rudra Bali    Male  24.0    Rural      Freelancer
# 4        5    Advait Malik    Male  48.0     City      Consultant
#
#    annual_income marital_status age_group
# 0       358211.0        Married     49-65
# 1        65172.0         Single     26-48
# 2        22378.0        Married     18-25
# 3        33563.0        Married     18-25
# 4        39406.0        Married     26-48

# %%
#This will give value_counts
df_cust.age_group.value_counts()
# Out:
# age_group
# 26-48    567
# 18-25    246
# 49-65    187
# Name: count, dtype: int64

# %%
#To Get The Percentage
age_group_counts = df_cust.age_group.value_counts(normalize=True)*100
age_group_counts
# Out:
# age_group
# 26-48    56.7
# 18-25    24.6
# 49-65    18.7
# Name: proportion, dtype: float64

# %%
type(age_group_counts)
# Out:
# pandas.core.series.Series

# %%
plt.pie(age_group_counts, labels = age_group_counts.index, autopct = '%1.2f%%',
        shadow=True,explode=(0.1,0,0), startangle=140 )
plt.title('Distribution of Age Groups')
plt.show()

# %%
df_cust.location.value_counts()
# Out:
# location
# City      683
# Suburb    232
# Rural      85
# Name: count, dtype: int64

# %%
df_cust.gender.value_counts()
# Out:
# gender
# Male      674
# Female    326
# Name: count, dtype: int64

# %%
df_cust.groupby(['location','gender']).size()
# Out:
# location  gender
# City      Female    226
#           Male      457
# Rural     Female     26
#           Male       59
# Suburb    Female     74
#           Male      158
# dtype: int64

# %%
#Convert it imto some datafram using unstack
customer_location_gender = df_cust.groupby(['location','gender']).size().unstack()
customer_location_gender
# Out:
# gender    Female  Male
# location
# City         226   457
# Rural         26    59
# Suburb        74   158

# %%
customer_location_gender.plot(kind="bar",stacked=True, figsize=(8,4))
plt.title('Customer Distribution by Location & Gender')
plt.legend(title='Gender')
plt.xlabel('Location')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# <h2>Explore Credit Score Table</h2>

# %%
df_cp.head()
# Out:
#    cust_id  credit_score  credit_utilisation  outstanding_debt  \
# 0        1           749            0.585171           19571.0
# 1        2           587            0.107928          161644.0
# 2        3           544            0.854807             513.0
# 3        4           504            0.336938             224.0
# 4        5           708            0.586151           18090.0
#
#    credit_inquiries_last_6_months  credit_limit
# 0                             0.0       40000.0
# 1                             2.0        1250.0
# 2                             4.0        1000.0
# 3                             2.0        1000.0
# 4                             2.0       40000.0

# %%
df_cp.shape
# Out:
# (1004, 6)

# %%
df_cust.shape
# Out:
# (1000, 9)

# %%
#So, check if there are any duplicates in credit score
df_cp['cust_id'].nunique()
# Out:
# 1000

# %%
#If want to see only duplicated values , duplicated function exist & pass the attribute as keep
df_cp[df_cp['cust_id'].duplicated(keep=False)]
# Out:
#      cust_id  credit_score  credit_utilisation  outstanding_debt  \
# 516      517           308                 NaN               NaN
# 517      517           308            0.113860              33.0
# 569      569           344                 NaN               NaN
# 570      569           344            0.112599              37.0
# 607      606           734                 NaN               NaN
# 608      606           734            0.193418            4392.0
# 664      662           442                 NaN               NaN
# 665      662           442            0.856039             266.0
#
#      credit_inquiries_last_6_months  credit_limit
# 516                             NaN           NaN
# 517                             3.0         500.0
# 569                             NaN           NaN
# 570                             0.0         500.0
# 607                             NaN           NaN
# 608                             1.0       40000.0
# ...

# %%
df_cp_clean_1 = df_cp.drop_duplicates(subset="cust_id",keep="last")
df_cp_clean_1.shape
# Out:
# (1000, 6)

# %%
df_cp_clean_1 [df_cp_clean_1 ['cust_id'].duplicated(keep=False)]
# Out:
# Empty DataFrame
# Columns: [cust_id, credit_score, credit_utilisation, outstanding_debt, credit_inquiries_last_6_months, credit_limit]
# Index: []

# %%
#Now check the null values
df_cp_clean_1.isnull().sum()
# Out:
# cust_id                            0
# credit_score                       0
# credit_utilisation                 0
# outstanding_debt                   0
# credit_inquiries_last_6_months     0
# credit_limit                      65
# dtype: int64

# %%
df_cp_clean_1[df_cp_clean_1.credit_limit.isnull()]
# Out:
#      cust_id  credit_score  credit_utilisation  outstanding_debt  \
# 10        11           679            0.557450            9187.0
# 35        36           790            0.112535            4261.0
# 37        38           514            0.296971             238.0
# 45        46           761            0.596041           24234.0
# 64        65           734            0.473715           13631.0
# ..       ...           ...                 ...               ...
# 912      909           479            0.487555             320.0
# 931      928           311            0.832244             316.0
# 948      945           526            0.272734             227.0
# 954      951           513            0.175914             131.0
# 957      954           783            0.867421           46451.0
#
#      credit_inquiries_last_6_months  credit_limit
# 10                              2.0           NaN
# 35                              1.0           NaN
# ...

# %%
df_cp_clean_1.credit_limit.value_counts()
# Out:
# credit_limit
# 500.0      229
# 60000.0    186
# 40000.0    137
# 1500.0     100
# 1000.0      90
# 750.0       76
# 1250.0      75
# 20000.0     42
# Name: count, dtype: int64

# %%
plt.scatter(df_cp_clean_1.credit_limit, df_cp_clean_1.credit_score)
plt.title('Credit Score vs Credit Limit')
plt.xlabel('Credit Limit')
plt.ylabel('Credit Score')

#Adjust the y-axis bin interval to 1000
plt.xticks(range(0,90001,5000))
plt.grid(True)

plt.legend()
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
bin_ranges = [300,450,500,550,600,650,700,750,800]
bin_labels = [f'{start}-{end-1}' for start,end in zip(bin_ranges, bin_ranges[1:])]

df_cp_clean_1['credit_score_range']=pd.cut(df_cp_clean_1['credit_score'],bins = bin_ranges, labels = bin_labels, include_lowest = True)

# %%
df_cp_clean_1.head()
# Out:
#    cust_id  credit_score  credit_utilisation  outstanding_debt  \
# 0        1           749            0.585171           19571.0
# 1        2           587            0.107928          161644.0
# 2        3           544            0.854807             513.0
# 3        4           504            0.336938             224.0
# 4        5           708            0.586151           18090.0
#
#    credit_inquiries_last_6_months  credit_limit credit_score_range
# 0                             0.0       40000.0            700-749
# 1                             2.0        1250.0            550-599
# 2                             4.0        1000.0            500-549
# 3                             2.0        1000.0            500-549
# 4                             2.0       40000.0            700-749

# %%
mode_df = df_cp_clean_1.groupby("credit_score_range")["credit_limit"].agg(lambda x: x.mode().iloc[0]).reset_index()
mode_df
# Out:
#   credit_score_range  credit_limit
# 0            300-449         500.0
# 1            450-499         750.0
# 2            500-549        1000.0
# 3            550-599        1250.0
# 4            600-649        1500.0
# 5            650-699       20000.0
# 6            700-749       40000.0
# 7            750-799       60000.0

# %%
df_cp_clean_2 = pd.merge(df_cp_clean_1, mode_df, on="credit_score_range", suffixes =("","_mode"))
df_cp_clean_2.sample(3)
# Out:
#      cust_id  credit_score  credit_utilisation  outstanding_debt  \
# 441      442           764            0.474390           18259.0
# 740      741           583            0.848684             562.0
# 686      687           736            0.738382           17882.0
#
#      credit_inquiries_last_6_months  credit_limit credit_score_range  \
# 441                             4.0       60000.0            750-799
# 740                             4.0        1250.0            550-599
# 686                             3.0           NaN            700-749
#
#      credit_limit_mode
# 441            60000.0
# 740             1250.0
# 686            40000.0

# %%
df_cp_clean_2[df_cp_clean_2.credit_limit.isnull()].sample(3)
# Out:
#      cust_id  credit_score  credit_utilisation  outstanding_debt  \
# 274      275           798            0.491995           19365.0
# 898      899           775            0.487290           21548.0
# 114      115           619            0.128910             151.0
#
#      credit_inquiries_last_6_months  credit_limit credit_score_range  \
# 274                             4.0           NaN            750-799
# 898                             0.0           NaN            750-799
# 114                             1.0           NaN            600-649
#
#      credit_limit_mode
# 274            60000.0
# 898            60000.0
# 114             1500.0

# %%
df_cp_clean_2['credit_limit'].fillna(df_cp_clean_2['credit_limit_mode'],inplace=True)

# %%
#Now check the null values
df_cp_clean_2.isnull().sum()
# Out:
# cust_id                           0
# credit_score                      0
# credit_utilisation                0
# outstanding_debt                  0
# credit_inquiries_last_6_months    0
# credit_limit                      0
# credit_score_range                0
# credit_limit_mode                 0
# dtype: int64

# %%
df_cp_clean_2.describe()
# Out:
#            cust_id  credit_score  credit_utilisation  outstanding_debt  \
# count  1000.000000   1000.000000         1000.000000       1000.000000
# mean    500.500000    589.182000            0.498950       9683.597000
# std     288.819436    152.284929            0.233139      25255.893671
# min       1.000000    300.000000            0.103761         33.000000
# 25%     250.750000    460.000000            0.293917        221.000000
# 50%     500.500000    601.500000            0.487422        550.000000
# 75%     750.250000    738.000000            0.697829      11819.500000
# max    1000.000000    799.000000            0.899648     209901.000000
#
#        credit_inquiries_last_6_months  credit_limit  credit_limit_mode
# count                     1000.000000   1000.000000        1000.000000
# mean                         1.955000  19733.500000       19733.500000
# std                          1.414559  24717.629112       24717.629112
# ...

# %%
sns.boxplot(x=df_cp_clean_2.outstanding_debt)
# Out:
# <Axes: xlabel='outstanding_debt'>

# %% [markdown]
# The circle above are outliers. Boxplot shows these circles using IQR method. Whenever we have to remove outlier, consult business manager & confirm the methodology.

# %%
df_cp_clean_2[df_cp_clean_2.outstanding_debt>df_cp_clean_2.credit_limit]
# Out:
#      cust_id  credit_score  credit_utilisation  outstanding_debt  \
# 1          2           587            0.107928          161644.0
# 19        20           647            0.439132          205014.0
# 25        26           758            0.250811          190838.0
# 38        39           734            0.573023          122758.0
# 93        94           737            0.739948          137058.0
# 204      205           303            0.364360          187849.0
# 271      272           703            0.446886          154568.0
# 301      302           722            0.608076          122402.0
# 330      331           799            0.363420          208898.0
# 350      351           320            0.285081          150860.0
# 446      447           754            0.178394          206191.0
# 544      545           764            0.337769          135112.0
# 636      637           420            0.323984          140063.0
# ...

# %%
df_cp_clean_2.loc[df_cp_clean_2.outstanding_debt>df_cp_clean_2.credit_limit,'outstanding_debt'] = df_cp_clean_2['credit_limit']

# %%
df_cp_clean_2[df_cp_clean_2.outstanding_debt>df_cp_clean_2.credit_limit]
# Out:
# Empty DataFrame
# Columns: [cust_id, credit_score, credit_utilisation, outstanding_debt, credit_inquiries_last_6_months, credit_limit, credit_score_range, credit_limit_mode]
# Index: []

# %%
df_cp_clean_2.loc[[6,12]]
# Out:
#     cust_id  credit_score  credit_utilisation  outstanding_debt  \
# 6         7           747            0.523965           15544.0
# 12       13           476            0.822498             318.0
#
#     credit_inquiries_last_6_months  credit_limit credit_score_range  \
# 6                              4.0       40000.0            700-749
# 12                             3.0         750.0            450-499
#
#     credit_limit_mode
# 6             40000.0
# 12              750.0

# %%
#Derive Strategies to treat outliers by consulting business managers. Most of the time, outlier treatment decision is based on business decision.

# %% [markdown]
# Correlation Among Credit Variables

# %% [markdown]
# Bivariate Analysis

# %%
df_cp_clean_2.head()
# Out:
#    cust_id  credit_score  credit_utilisation  outstanding_debt  \
# 0        1           749            0.585171           19571.0
# 1        2           587            0.107928            1250.0
# 2        3           544            0.854807             513.0
# 3        4           504            0.336938             224.0
# 4        5           708            0.586151           18090.0
#
#    credit_inquiries_last_6_months  credit_limit credit_score_range  \
# 0                             0.0       40000.0            700-749
# 1                             2.0        1250.0            550-599
# 2                             4.0        1000.0            500-549
# 3                             2.0        1000.0            500-549
# 4                             2.0       40000.0            700-749
#
#    credit_limit_mode
# 0            40000.0
# 1             1250.0
# 2             1000.0
# 3             1000.0
# 4            40000.0

# %%
df_cust.head()
# Out:
#    cust_id            name  gender   age location      occupation  \
# 0        1   Manya Acharya  Female  51.0     City  Business Owner
# 1        2   Anjali Pandey  Female  47.0     City      Consultant
# 2        3  Aaryan Chauhan    Male  21.0     City      Freelancer
# 3        4      Rudra Bali    Male  24.0    Rural      Freelancer
# 4        5    Advait Malik    Male  48.0     City      Consultant
#
#    annual_income marital_status age_group
# 0       358211.0        Married     49-65
# 1        65172.0         Single     26-48
# 2        22378.0        Married     18-25
# 3        33563.0        Married     18-25
# 4        39406.0        Married     26-48

# %%
df_merged=df_cust.merge(df_cp_clean_2, on="cust_id",how="inner")
df_merged.head(4)
# Out:
#    cust_id            name  gender   age location      occupation  \
# 0        1   Manya Acharya  Female  51.0     City  Business Owner
# 1        2   Anjali Pandey  Female  47.0     City      Consultant
# 2        3  Aaryan Chauhan    Male  21.0     City      Freelancer
# 3        4      Rudra Bali    Male  24.0    Rural      Freelancer
#
#    annual_income marital_status age_group  credit_score  credit_utilisation  \
# 0       358211.0        Married     49-65           749            0.585171
# 1        65172.0         Single     26-48           587            0.107928
# 2        22378.0        Married     18-25           544            0.854807
# 3        33563.0        Married     18-25           504            0.336938
#
#    outstanding_debt  credit_inquiries_last_6_months  credit_limit  \
# 0           19571.0                             0.0       40000.0
# 1            1250.0                             2.0        1250.0
# ...

# %%
#Establising Corelations
numerical_cols = ['credit_score','credit_utilisation','outstanding_debt','credit_limit','annual_income','age']
correlation_matrix = df_merged[numerical_cols].corr()
correlation_matrix
# Out:
#                     credit_score  credit_utilisation  outstanding_debt  \
# credit_score            1.000000           -0.070445          0.680654
# credit_utilisation     -0.070445            1.000000          0.192838
# outstanding_debt        0.680654            0.192838          1.000000
# credit_limit            0.847951           -0.080504          0.810581
# annual_income           0.575751           -0.086368          0.555661
# age                     0.444917           -0.027713          0.444301
#
#                     credit_limit  annual_income       age
# credit_score            0.847951       0.575751  0.444917
# credit_utilisation     -0.080504      -0.086368 -0.027713
# outstanding_debt        0.810581       0.555661  0.444301
# credit_limit            1.000000       0.684780  0.510980
# annual_income           0.684780       1.000000  0.619037
# age                     0.510980       0.619037  1.000000

# %%
#Having Knowledge of Corelation is useful in Data Science
sns.heatmap(correlation_matrix, annot=True, fmt=".2f",cmap='coolwarm', linewidths=0.8)
plt.title('Corelation Plot')
plt.show()

# %% [markdown]
# Transactions Table

# %%
df_trans.head()
# Out:
#    tran_id  cust_id   tran_date  tran_amount  platform   product_category  \
# 0        1      705  2023-01-01           63  Flipkart        Electronics
# 1        2      385  2023-01-01           99   Alibaba  Fashion & Apparel
# 2        3      924  2023-01-01          471   Shopify             Sports
# 3        4      797  2023-01-01           33   Shopify  Fashion & Apparel
# 4        5      482  2023-01-01           68    Amazon  Fashion & Apparel
#
#   payment_type
# 0      Phonepe
# 1  Credit Card
# 2      Phonepe
# 3         Gpay
# 4  Net Banking

# %%
df_trans.shape
# Out:
# (500000, 7)

# %%
df_trans.isnull().sum()
# Out:
# tran_id                0
# cust_id                0
# tran_date              0
# tran_amount            0
# platform            4941
# product_category       0
# payment_type           0
# dtype: int64

# %%
df_trans[df_trans.platform.isnull()]
# Out:
#         tran_id  cust_id   tran_date  tran_amount platform   product_category  \
# 355         356       58  2023-01-01          237      NaN        Electronics
# 418         419      383  2023-01-01          338      NaN        Electronics
# 607         608      421  2023-01-01          700      NaN        Electronics
# 844         845      945  2023-01-01          493      NaN             Sports
# 912         913      384  2023-01-01           85      NaN  Fashion & Apparel
# ...         ...      ...         ...          ...      ...                ...
# 499579   499580      924  2023-09-05           31      NaN  Fashion & Apparel
# 499646   499647      944  2023-09-05        58445      NaN  Fashion & Apparel
# 499725   499726      620  2023-09-05           15      NaN             Sports
# 499833   499834      616  2023-09-05           97      NaN  Fashion & Apparel
# 499997   499998       57  2023-09-05          224      NaN   Garden & Outdoor
#
#        payment_type
# ...

# %%
df_trans.platform.unique()
# Out:
# array(['Flipkart', 'Alibaba', 'Shopify', 'Amazon', 'Ebay', 'Meesho',
#        'Cred', nan], dtype=object)

# %%
df_trans.platform.mode()
# Out:
# 0    Amazon
# Name: platform, dtype: object

# %%
df_trans.platform.value_counts()
# Out:
# platform
# Amazon      151443
# Flipkart    122660
# Alibaba      73584
# Meesho       73271
# Shopify      39416
# Cred         24741
# Ebay          9944
# Name: count, dtype: int64

# %%
sns.countplot(y="product_category",hue="platform",data=df_trans)
# Out:
# <Axes: xlabel='count', ylabel='product_category'>

# %%
df_trans.platform.mode()[0]
# Out:
# 'Amazon'

# %%
df_trans.platform.fillna(df_trans.platform.mode()[0],inplace=True)

# %%
df_trans.isnull().sum()
# Out:
# tran_id             0
# cust_id             0
# tran_date           0
# tran_amount         0
# platform            0
# product_category    0
# payment_type        0
# dtype: int64

# %%
df_trans.describe()
# Out:
#              tran_id        cust_id   tran_amount
# count  500000.000000  500000.000000  500000.00000
# mean   250000.500000     501.400428    3225.20733
# std    144337.711635     288.641924   13098.74276
# min         1.000000       1.000000       0.00000
# 25%    125000.750000     252.000000      64.00000
# 50%    250000.500000     502.000000     141.00000
# 75%    375000.250000     752.000000     397.00000
# max    500000.000000    1000.000000   69999.00000

# %%
df_trans_zero = df_trans[df_trans.tran_amount==0]
df_trans_zero
# Out:
#         tran_id  cust_id   tran_date  tran_amount platform product_category  \
# 120         121      440  2023-01-01            0   Amazon      Electronics
# 141         142      839  2023-01-01            0   Amazon      Electronics
# 517         518      147  2023-01-01            0   Amazon      Electronics
# 533         534      891  2023-01-01            0   Amazon      Electronics
# 586         587      108  2023-01-01            0   Amazon      Electronics
# ...         ...      ...         ...          ...      ...              ...
# 499326   499327      695  2023-09-05            0   Amazon      Electronics
# 499494   499495      295  2023-09-05            0   Amazon      Electronics
# 499708   499709      141  2023-09-05            0   Amazon      Electronics
# 499928   499929        4  2023-09-05            0   Amazon      Electronics
# 499972   499973      224  2023-09-05            0   Amazon      Electronics
#
#        payment_type
# 120     Credit Card
# ...

# %%
df_trans_zero.head()
# Out:
#      tran_id  cust_id   tran_date  tran_amount platform product_category  \
# 120      121      440  2023-01-01            0   Amazon      Electronics
# 141      142      839  2023-01-01            0   Amazon      Electronics
# 517      518      147  2023-01-01            0   Amazon      Electronics
# 533      534      891  2023-01-01            0   Amazon      Electronics
# 586      587      108  2023-01-01            0   Amazon      Electronics
#
#     payment_type
# 120  Credit Card
# 141  Credit Card
# 517  Credit Card
# 533  Credit Card
# 586  Credit Card

# %%
df_trans_zero.platform.value_counts()
# Out:
# platform
# Amazon    4734
# Name: count, dtype: int64

# %%
df_trans_zero[["platform","product_category","payment_type"]].value_counts()
# Out:
# platform  product_category  payment_type
# Amazon    Electronics       Credit Card     4734
# Name: count, dtype: int64

# %%
df_trans_1 = df_trans[(df_trans.platform=='Amazon') & (df_trans.product_category=="Electronics") & (df_trans.payment_type=="Credit Card")]
df_trans_1.head()
# Out:
#      tran_id  cust_id   tran_date  tran_amount platform product_category  \
# 109      110      887  2023-01-01          635   Amazon      Electronics
# 120      121      440  2023-01-01            0   Amazon      Electronics
# 141      142      839  2023-01-01            0   Amazon      Electronics
# 173      174      676  2023-01-01        60439   Amazon      Electronics
# 190      191      763  2023-01-01          697   Amazon      Electronics
#
#     payment_type
# 109  Credit Card
# 120  Credit Card
# 141  Credit Card
# 173  Credit Card
# 190  Credit Card

# %%
median_to_replace = df_trans_1[df_trans_1.tran_amount>0].tran_amount.median()
median_to_replace
# Out:
# 554.0

# %%
df_trans["tran_amount"].replace(0,median_to_replace, inplace = True)

# %%
df_trans.describe()
# Out:
#              tran_id        cust_id    tran_amount
# count  500000.000000  500000.000000  500000.000000
# mean   250000.500000     501.400428    3230.452602
# std    144337.711635     288.641924   13097.561071
# min         1.000000       1.000000       2.000000
# 25%    125000.750000     252.000000      66.000000
# 50%    250000.500000     502.000000     146.000000
# 75%    375000.250000     752.000000     413.000000
# max    500000.000000    1000.000000   69999.000000

# %%
sns.histplot(df_trans[df_trans.tran_amount<10000].tran_amount, bins=30)
# Out:
# <Axes: xlabel='tran_amount', ylabel='Count'>

# %%
Q1, Q3 = df_trans['tran_amount'].quantile([0.25,0.75])
IQR = Q3- Q1
lower = Q1 - 2*IQR
upper = Q3 + 2*IQR

lower, upper
# Out:
# (-628.0, 1107.0)

# %%
df_tran_outliers = df_trans[df_trans.tran_amount>=upper]
df_tran_outliers.shape
# Out:
# (25000, 7)

# %%
df_trans_normal = df_trans[df_trans.tran_amount<upper]
df_trans_normal.head()
# Out:
#    tran_id  cust_id   tran_date  tran_amount  platform   product_category  \
# 0        1      705  2023-01-01           63  Flipkart        Electronics
# 1        2      385  2023-01-01           99   Alibaba  Fashion & Apparel
# 2        3      924  2023-01-01          471   Shopify             Sports
# 3        4      797  2023-01-01           33   Shopify  Fashion & Apparel
# 4        5      482  2023-01-01           68    Amazon  Fashion & Apparel
#
#   payment_type
# 0      Phonepe
# 1  Credit Card
# 2      Phonepe
# 3         Gpay
# 4  Net Banking

# %%
trans_mean_per_category = df_trans_normal.groupby("product_category")["tran_amount"].mean()
trans_mean_per_category
# Out:
# product_category
# Beauty & Personal Care     92.167205
# Books                      29.553515
# Electronics               510.172685
# Fashion & Apparel          64.553463
# Garden & Outdoor          125.630277
# Home Decor                302.487561
# Kitchen Appliances        176.773288
# Sports                    269.181631
# Toys & Games               50.333298
# Name: tran_amount, dtype: float64

# %%
df_trans.loc[df_tran_outliers.index,"tran_amount"] = df_tran_outliers['product_category'].map(trans_mean_per_category)

# %%
df_trans.loc[df_tran_outliers.index]
# Out:
#         tran_id  cust_id   tran_date  tran_amount  platform  \
# 26           27      380  2023-01-01    92.167205   Shopify
# 49           50      287  2023-01-01    50.333298    Amazon
# 94           95      770  2023-01-01   176.773288      Ebay
# 104         105      549  2023-01-01    64.553463  Flipkart
# 113         114      790  2023-01-01   176.773288   Shopify
# ...         ...      ...         ...          ...       ...
# 499742   499743      868  2023-09-05    64.553463    Meesho
# 499888   499889      614  2023-09-05    64.553463    Meesho
# 499900   499901      811  2023-09-05   269.181631  Flipkart
# 499966   499967      662  2023-09-05   269.181631    Meesho
# 499996   499997      569  2023-09-05    64.553463    Meesho
#
#               product_category payment_type
# 26      Beauty & Personal Care  Credit Card
# 49                Toys & Games         Gpay
# 94          Kitchen Appliances  Credit Card
# 104          Fashion & Apparel         Gpay
# ...

# %%
df_trans.head()
# Out:
#    tran_id  cust_id   tran_date  tran_amount  platform   product_category  \
# 0        1      705  2023-01-01         63.0  Flipkart        Electronics
# 1        2      385  2023-01-01         99.0   Alibaba  Fashion & Apparel
# 2        3      924  2023-01-01        471.0   Shopify             Sports
# 3        4      797  2023-01-01         33.0   Shopify  Fashion & Apparel
# 4        5      482  2023-01-01         68.0    Amazon  Fashion & Apparel
#
#   payment_type
# 0      Phonepe
# 1  Credit Card
# 2      Phonepe
# 3         Gpay
# 4  Net Banking

# %%
sns.histplot(df_trans.tran_amount, kde=True, bins = 20)
# Out:
# <Axes: xlabel='tran_amount', ylabel='Count'>

# %%
sns.countplot(x=df_trans.payment_type, stat = 'percent')
# Out:
# <Axes: xlabel='payment_type', ylabel='percent'>

# %%
#Merging the datasets: customer, credit profile & transactions
df_merged_2 = pd.merge(df_merged, df_trans, on = "cust_id", how="inner")
df_merged_2.head(3)
# Out:
#    cust_id           name  gender   age location      occupation  \
# 0        1  Manya Acharya  Female  51.0     City  Business Owner
# 1        1  Manya Acharya  Female  51.0     City  Business Owner
# 2        1  Manya Acharya  Female  51.0     City  Business Owner
#
#    annual_income marital_status age_group  credit_score  ...  \
# 0       358211.0        Married     49-65           749  ...
# 1       358211.0        Married     49-65           749  ...
# 2       358211.0        Married     49-65           749  ...
#
#    credit_inquiries_last_6_months  credit_limit  credit_score_range  \
# 0                             0.0       40000.0             700-749
# 1                             0.0       40000.0             700-749
# 2                             0.0       40000.0             700-749
#
#    credit_limit_mode tran_id   tran_date  tran_amount platform  \
# 0            40000.0    1283  2023-01-01         30.0  Shopify
# ...

# %%
sns.countplot(x= 'age_group',hue='payment_type', data = df_merged_2)
plt.title("Distribution of Payment Types across Age Group")
# Out:
# Text(0.5, 1.0, 'Distribution of Payment Types across Age Group')

# %%
fig, (ax1, ax2) = plt.subplots(1,2, figsize=(12,5))

sns.countplot(x='age_group', hue="product_category", data=df_merged_2, ax=ax1)
ax1.set_title("Product Category Count By Age Group")
ax1.set_xlabel("Age Group")
ax1.set_ylabel("Count")
ax1.legend(title="Product Category", loc='upper right')

sns.countplot(x='age_group', hue="platform", data=df_merged_2, ax=ax2)
ax2.set_title("Platform Count By Age Group")
ax2.set_xlabel("Age Group")
ax2.set_ylabel("Count")
ax2.legend(title="Product Category", loc='upper right')

plt.show()

# %%
# List of categorical columns
cat_cols = ['payment_type', 'platform', 'product_category', 'marital_status', 'age_group']

num_rows = 3
# Create subplots
fig, axes = plt.subplots(num_rows, 2, figsize=(12, 4 * num_rows))

# Flatten the axes array to make it easier to iterate
axes = axes.flatten()

# Create subplots for each categorical column
for i, cat_col in enumerate(cat_cols):
    # Calculate the average annual income for each category
    avg_tran_amount_by_category = df_merged_2.groupby(cat_col)['tran_amount'].mean().reset_index()
    
    # Sort the data by 'annual_income' before plotting
    sorted_data = avg_tran_amount_by_category.sort_values(by='tran_amount', ascending=False)
    
    sns.barplot(x=cat_col, y='tran_amount', data=sorted_data, ci=None, ax=axes[i], palette='tab10')
    axes[i].set_title(f'Average transaction amount by {cat_col}')
    axes[i].set_xlabel(cat_col)
    axes[i].set_ylabel('Average transaction amount')

    # Rotate x-axis labels for better readability
    axes[i].set_xticklabels(axes[i].get_xticklabels(), rotation=45)

# Hide any unused subplots
for i in range(len(cat_cols), len(axes)):
    fig.delaxes(axes[i])
plt.tight_layout()
plt.show()

# %%
# Group the data by age group and calculate the average credit_limit and credit_score
age_group_metrics = df_merged.groupby('age_group')[['annual_income', 'credit_limit', 'credit_score']].mean().reset_index()
age_group_metrics
# Out:
#   age_group  annual_income  credit_limit  credit_score
# 0     18-25   37091.235772   1130.081301    484.451220
# 1     26-48  145869.623457  20560.405644    597.569665
# 2     49-65  260165.925134  41699.197861    701.524064

# %%
# Create subplots
fig, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize=(12, 4))

# Plot 1: Average annual income by age group
sns.barplot(x='age_group', y='annual_income', data=age_group_metrics, palette='tab10', ax=ax1)
ax1.set_title('Average Annual Income by Age Group')
ax1.set_xlabel('Age Group')
ax1.set_ylabel('Average Annual Income')
ax1.tick_params(axis='x', rotation=0)

# Plot 2: Average Max Credit Limit by Age Group
sns.barplot(x='age_group', y='credit_limit', data=age_group_metrics, palette='hls', ax=ax2)
ax2.set_title('Average Credit Limit by Age Group')
ax2.set_xlabel('Age Group')
ax2.set_ylabel('Average Credit Limit')
ax2.tick_params(axis='x', rotation=0)

# Plot 3: Average Credit Score by Age Group
sns.barplot(x='age_group', y='credit_score', data=age_group_metrics, palette='viridis', ax=ax3)
ax3.set_title('Average Credit Score by Age Group')
ax3.set_xlabel('Age Group')
ax3.set_ylabel('Average Credit Score')
ax3.tick_params(axis='x', rotation=0)

plt.tight_layout()
plt.show()

# %% [markdown]
# **Targetting Untapped Market**
# 1. People with age group of 18-25 accounts to 26% of customer base in the data.
# 2. Avg annual income of this group is less than 50k
# 3. They dont have much credit history which is getting reflected in their credit score & credit limit
# 4. Usage of Credit Cards as payment type is relatively low compared to other groups
# 5. Top 3 most shopping products categories: Electronics, Fashion & Apparel, Beauty & Personal Care

# %%
df_test = pd.DataFrame({
    'Category': ['Electronics', 'Clothing', 'Electronics', 'Clothing'],
    'TimeOfDay': ['Morning', 'Afternoon', 'Evening', 'Morning'],
    'Sales': [300, 150, 500, 200]
})

# %%
#The idxmax() method returns a Series with the index of the maximum value for each column.

By specifying the column axis (axis='columns'), the idxmax() method returns a Series with the index of the maximum value for each row.
peak_sales = df.pivot_table(index='Category', columns='TimeOfDay', values='Sales', aggfunc='sum').idxmax(axis=1)
print(peak_sales)
# Out:
# Category
# Clothing       Morning
# Electronics    Evening
# dtype: object
